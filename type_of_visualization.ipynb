# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cấu hình giao diện đẹp
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# Load dữ liệu
df = pd.read_csv('FoAI_A2_data_4.6k.csv')

# Sắp xếp thứ tự logic cho các biến phân loại (Rất quan trọng để biểu đồ dễ hiểu)
exp_order = ['EN', 'MI', 'SE', 'EX']  # Entry -> Mid -> Senior -> Executive
size_order = ['S', 'M', 'L']          # Small -> Medium -> Large
